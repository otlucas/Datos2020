# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Descargas/entrenamiento.csv')
data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data['tweet_length'] = data['text'].transform(lambda x: len(x.split()))
data
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# 5         8     NaN      NaN
# 6        10     NaN      NaN
# 7        13     NaN      NaN
# 8        14     NaN      NaN
# 9        15     NaN      NaN
# 10       16     NaN      NaN
# 11       17     NaN      NaN
# 12       18     NaN      NaN
# 13       19     NaN      NaN
# 14       20     NaN      NaN
# 15       23     NaN      NaN
# 16       24     NaN      NaN
# 17       25     NaN      NaN
# 18       26     NaN      NaN
# 19       28     NaN      NaN
# 20       31     NaN      NaN
# 21       32     NaN      NaN
# 22       33     NaN      NaN
# 23       34     NaN      NaN
# 24       36     NaN      NaN
# 25       37     NaN      NaN
# 26       38     NaN      NaN
# 27       39     NaN      NaN
# 28       40     NaN      NaN
# 29       41     NaN      NaN
# ...     ...     ...      ...
# 7583  10835     NaN      NaN
# 7584  10837     NaN      NaN
# 7585  10839     NaN      NaN
# 7586  10840     NaN      NaN
# 7587  10841     NaN      NaN
# 7588  10842     NaN      NaN
# 7589  10843     NaN      NaN
# 7590  10844     NaN      NaN
# 7591  10846     NaN      NaN
# 7592  10847     NaN      NaN
# 7593  10848     NaN      NaN
# 7594  10849     NaN      NaN
# 7595  10850     NaN      NaN
# 7596  10851     NaN      NaN
# 7597  10852     NaN      NaN
# 7598  10853     NaN      NaN
# 7599  10854     NaN      NaN
# 7600  10855     NaN      NaN
# 7601  10859     NaN      NaN
# 7602  10860     NaN      NaN
# 7603  10862     NaN      NaN
# 7604  10863     NaN      NaN
# 7605  10864     NaN      NaN
# 7606  10866     NaN      NaN
# 7607  10867     NaN      NaN
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  tweet_length
# 0     Our Deeds are the Reason of this #earthquake M...       1            13
# 1                Forest fire near La Ronge Sask. Canada       1             7
# 2     All residents asked to 'shelter in place' are ...       1            22
# 3     13,000 people receive #wildfires evacuation or...       1             8
# 4     Just got sent this photo from Ruby #Alaska as ...       1            16
# 5     #RockyFire Update => California Hwy. 20 closed...       1            18
# 6     #flood #disaster Heavy rain causes flash flood...       1            14
# 7     I'm on top of the hill and I can see a fire in...       1            15
# 8     There's an emergency evacuation happening now ...       1            12
# 9     I'm afraid that the tornado is coming to our a...       1            10
# 10          Three people died from the heat wave so far       1             9
# 11    Haha South Tampa is getting flooded hah- WAIT ...       1            27
# 12    #raining #flooding #Florida #TampaBay #Tampa 1...       1            12
# 13              #Flood in Bago Myanmar #We arrived Bago       1             7
# 14    Damage to school bus on 80 in multi car crash ...       1            11
# 15                                       What's up man?       0             3
# 16                                        I love fruits       0             3
# 17                                     Summer is lovely       0             3
# 18                                    My car is so fast       0             5
# 19                         What a goooooooaaaaaal!!!!!!       0             3
# 20                               this is ridiculous....       0             3
# 21                                    London is cool ;)       0             4
# 22                                          Love skiing       0             2
# 23                                What a wonderful day!       0             4
# 24                                             LOOOOOOL       0             1
# 25                       No way...I can't eat that shit       0             6
# 26                                Was in NYC last week!       0             5
# 27                                   Love my girlfriend       0             3
# 28                                            Cooool :)       0             2
# 29                                   Do you like pasta?       0             4
# ...                                                 ...     ...           ...
# 7583  Pic of 16yr old PKK suicide bomber who detonat...       1            17
# 7584  These boxes are ready to explode! Exploding Ki...       0            13
# 7585  Calgary Police Flood Road Closures in Calgary....       1             8
# 7586  #Sismo DETECTADO #JapÌ_n 15:41:07 Seismic inte...       1            12
# 7587                                 Sirens everywhere!       0             2
# 7588  BREAKING: #ISIS claims responsibility for mosq...       1            15
# 7589                                     Omg earthquake       1             2
# 7590  SEVERE WEATHER BULLETIN No. 5 FOR: TYPHOON ÛÏ...       1            19
# 7591  Heat wave warning aa? Ayyo dei. Just when I pl...       1            16
# 7592  An IS group suicide bomber detonated an explos...       1            21
# 7593  I just heard a really loud bang and everyone i...       0            12
# 7594  A gas thing just exploded and I heard screams ...       1            19
# 7595  NWS: Flash Flood Warning Continued for Shelby ...       1            14
# 7596  RT @LivingSafely: #NWS issues Severe #Thunders...       1            18
# 7597  #??? #?? #??? #??? MH370: Aircraft debris foun...       1            18
# 7598  Father-of-three Lost Control of Car After Over...       1            11
# 7599  1.3 #Earthquake in 9Km Ssw Of Anza California ...       1            18
# 7600  Evacuation order lifted for town of Roosevelt:...       1             9
# 7601  #breaking #LA Refugio oil spill may have been ...       1            13
# 7602  a siren just went off and it wasn't the Forney...       1            13
# 7603  Officials say a quarantine is in place at an A...       1            20
# 7604  #WorldNews Fallen powerlines on G:link tram: U...       1            19
# 7605  on the flip side I'm at Walmart and there is a...       1            26
# 7606  Suicide bomber kills 15 in Saudi security site...       1            20
# 7607  #stormchase Violent Record Breaking EF-5 El Re...       1            16
# 7608  Two giant cranes holding a bridge collapse int...       1            11
# 7609  @aria_ahrary @TheTawniest The out of control w...       1            20
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1             8
# 7611  Police investigating after an e-bike collided ...       1            19
# 7612  The Latest: More Homes Razed by Northern Calif...       1            13
#
# [7613 rows x 6 columns]

# %%
datos_segun_longitud = data.groupby(['tweet_length']).agg({'target':['mean','count','sum']})
datos_segun_longitud.reset_index(inplace=True)
columns = ['Longitud','Promedio_Target','Cantidad_Tweets','Cantidad_Tweets_Con_Target_1']
datos_segun_longitud.columns = columns
datos_segun_longitud['Cantidad_Tweets_Con_Target_0'] = datos_segun_longitud['Cantidad_Tweets'] - datos_segun_longitud['Cantidad_Tweets_Con_Target_1']
datos_segun_longitud.head()
# Out:
#    Longitud  Promedio_Target  Cantidad_Tweets  Cantidad_Tweets_Con_Target_1  \
# 0         1         0.000000                8                             0
# 1         2         0.117647               34                             4
# 2         3         0.173333               75                            13
# 3         4         0.208696              115                            24
# 4         5         0.245283              159                            39
#
#    Cantidad_Tweets_Con_Target_0
# 0                             8
# 1                            30
# 2                            62
# 3                            91
# 4                           120

# %%
fig,ax = plt.subplots(figsize=(20,10))

fig.tight_layout()

ax.bar(datos_segun_longitud['Longitud'],datos_segun_longitud['Cantidad_Tweets'],label='Tweets totales',alpha= 0.2,color='darkgrey')
ax.bar(datos_segun_longitud['Longitud'],datos_segun_longitud['Cantidad_Tweets_Con_Target_0'],label='Tweets con Informacion falsa',alpha=1,color='orangered')
ax.bar(datos_segun_longitud['Longitud'],datos_segun_longitud['Cantidad_Tweets_Con_Target_1'],label='Tweets con Informacion real',alpha=0.8,color='darkseagreen')
ax.legend(prop={'size':20})
ax.set_ylabel('Cantidad de Tweets',size=15)
ax.set_title('Comparacion de Cantidad de Tweets segun su longitud y su veracidad',size=25)
ax.set_xlabel('Cantidad de Palabras Por Tweet',size=15)
plt.savefig('Finger.png',bbox_inches='tight')
plt.show()

# %%
data = pd.read_csv('../Descargas/entrenamiento.csv')
data.head()
# Out:
#    id keyword location  \
# 0  1   NaN     NaN
# 1  4   NaN     NaN
# 2  5   NaN     NaN
# 3  6   NaN     NaN
# 4  7   NaN     NaN
#
#                                                                                                                                     text  \
# 0  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1  Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3  13,000 people receive #wildfires evacuation orders in California
# 4  Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
palabras_por_separado = data
palabras_por_separado.set_index(['id','target'],inplace=True)

# %%
import re 
from string import punctuation


palabras_por_separado = palabras_por_separado['text'].str.split(expand=True).stack().to_frame()

# %%
palabras_por_separado.columns = ['word']
palabras_por_separado['word'] = palabras_por_separado['word'].str.replace(rf'[{punctuation}]', '')

# %%
palabras_por_separado.reset_index(inplace=True)
del palabras_por_separado['level_2']

# %%
from wordcloud import WordCloud,STOPWORDS

palabras_de_tweets_reales = palabras_por_separado.loc[palabras_por_separado['target'] == 1]

# %%
palabras_de_tweets_reales.loc[palabras_de_tweets_reales['word'] == 'thi']
# Out:
# Empty DataFrame
# Columns: [id, target, word]
# Index: []

# %%
lista_palabras = palabras_de_tweets_reales['word'].to_list()
string_palabras = " ".join(word for word in lista_palabras)
string_palabras = string_palabras.lower()

# %%
wc = WordCloud(min_word_length = 4,background_color= 'white',min_font_size= 40,max_font_size = 300,max_words = 200,width = 5000,height = 2500).generate(string_palabras)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.savefig('PalabrasReales.png',bbox_inches='tight')
plt.show()

# %%
palabras_de_tweets_falsas = palabras_por_separado.loc[palabras_por_separado['target'] == 0]
lista_palabras_falsas= palabras_de_tweets_falsas['word'].to_list()
string_palabras_falsas = " ".join(word for word in lista_palabras_falsas)
string_palabras_falsas = string_palabras_falsas.lower()
string_palabras_falsas
wc2 = WordCloud(min_word_length = 4,background_color= 'white',min_font_size= 40,max_font_size = 400,max_words = 200,width = 5000,height = 2500).generate(string_palabras_falsas)
plt.imshow(wc2, interpolation='bilinear')
plt.axis("off")
plt.savefig('PalabrasFalsas.png',bbox_inches='tight')
plt.show()

# %%
data = pd.read_csv('../Descargas/entrenamiento.csv')
data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# Quiero ver si existe una relacion entre la cantidad de mayusculas de un mensaje y la veracidad o falsedad
# Para eso busco el porcentaje de mayusculas que tiene cada mensaje y genero una visualizacion de la relacion

# %%
porcentaje_mayusculas = data
porcentaje_mayusculas['cant_mayusculas'] = porcentaje_mayusculas['text'].apply(lambda x: sum(1 for c in x if c.isupper()))

# %%
porcentaje_mayusculas['cant_caracteres'] = porcentaje_mayusculas['text'].apply(lambda x: len(x))
porcentaje_mayusculas['porcentaje_mayusculas'] = (porcentaje_mayusculas['cant_mayusculas']/porcentaje_mayusculas['cant_caracteres'])*100
porcentaje_mayusculas['porcentaje_minusculas'] = 100 - porcentaje_mayusculas['porcentaje_mayusculas']
porcentaje_mayusculas.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target  cant_mayusculas  cant_caracteres  porcentaje_mayusculas  \
# 0       1               10               69              14.492754
# 1       1                5               38              13.157895
# 2       1                2              133               1.503759
# 3       1                1               65               1.538462
# 4       1                3               88               3.409091
#
#    porcentaje_minusculas
# 0              85.507246
# 1              86.842105
# 2              98.496241
# 3              98.461538
# 4              96.590909

# %%
data = pd.read_csv('../Descargas/entrenamiento.csv')
data.head()
# Out:
#    id keyword location  \
# 0  1   NaN     NaN
# 1  4   NaN     NaN
# 2  5   NaN     NaN
# 3  6   NaN     NaN
# 4  7   NaN     NaN
#
#                                                                                                                                     text  \
# 0  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1  Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3  13,000 people receive #wildfires evacuation orders in California
# 4  Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
data['text'] = data['text'].apply(lambda x: x.lower())

# %%
dic = list(dict.fromkeys(data['keyword'].to_list()))
dic.pop(0)
for word in dic:
    index = dic.index(word)
    dic[index] = word.replace('%20',' ')

# %%
import re
def suma_de_keywords(lista,string):
    x= 0
    for word in lista:
        x += 1 if (word in string.lower()) else 0
    return x

# %%
data['cant_keywords'] = data['text'].apply(lambda x: suma_de_keywords(dic,x))
pd.set_option('display.max_colwidth', -1)

# %%
df = data.loc[data['cant_keywords'] <= 5]

# %%
nueva_data = data.loc[data['cant_keywords'] == 0]
nueva_data
# Out:
#          id          keyword                       location  \
# 15    23     NaN              NaN
# 16    24     NaN              NaN
# 17    25     NaN              NaN
# 18    26     NaN              NaN
# 19    28     NaN              NaN
# 20    31     NaN              NaN
# 21    32     NaN              NaN
# 22    33     NaN              NaN
# 23    34     NaN              NaN
# 24    36     NaN              NaN
# 25    37     NaN              NaN
# 26    38     NaN              NaN
# 27    39     NaN              NaN
# 28    40     NaN              NaN
# 29    41     NaN              NaN
# 30    44     NaN              NaN
# 32    49     ablaze           Est. September 2012 - Bristol
# 40    59     ablaze           Live On Webcam
# 45    65     ablaze           NaN
# 48    68     ablaze           Live On Webcam
# 49    71     ablaze           England.
# 54    78     ablaze           Abuja
# 103   149    aftershock       304
# 105   153    aftershock       304
# 107   157    aftershock       304
# 109   159    aftershock       304
# 120   173    aftershock       Oshawa, Canada
# 125   180    aftershock       304
# 126   182    aftershock       304
# 127   183    aftershock       marysville ca
# ...   ...           ...                  ...
# 6917  9919   trouble          NaN
# 6937  9948   trouble          Palo Alto, CA
# 6943  9958   tsunami          NaN
# 6949  9971   tsunami          Louavul, KY
# 6952  9974   tsunami          IG : Sincerely_TSUNAMI
# 6975  10005  tsunami          NaN
# 6995  10031  twister          NaN
# 7066  10120  upheaval         NYC
# 7073  10130  upheaval         Wisconsin, USA
# 7076  10137  upheaval         Woosley
# 7077  10138  upheaval         NaN
# 7078  10139  upheaval         London, UK
# 7079  10140  upheaval         Costa Rica
# 7080  10141  upheaval         Hamilton, Ontario CA
# 7082  10143  upheaval         Attock
# 7088  10151  upheaval         London, UK
# 7098  10171  violent%20storm  NaN
# 7104  10177  violent%20storm  NaN
# 7154  10251  war%20zone       Incognito
# 7165  10268  war%20zone       The D
# 7197  10310  weapon           Washington DC
# 7219  10338  weapons          Odawara, Japan
# 7241  10369  weapons          NaN
# 7243  10372  weapons          NaN
# 7264  10399  whirlwind        140920-21 & 150718-19 BEIJING
# 7272  10411  whirlwind        140920-21 & 150718-19 BEIJING
# 7334  10499  wildfire         Ashland, Oregon
# 7342  10513  wildfire         Columbus, OH
# 7440  10647  wounds           Kashmir!
# 7494  10721  wreck            Greenville
#
#                                                                                                                                               text  \
# 15    what's up man?
# 16    i love fruits
# 17    summer is lovely
# 18    my car is so fast
# 19    what a goooooooaaaaaal!!!!!!
# 20    this is ridiculous....
# 21    london is cool ;)
# 22    love skiing
# 23    what a wonderful day!
# 24    looooool
# 25    no way...i can't eat that shit
# 26    was in nyc last week!
# 27    love my girlfriend
# 28    cooool :)
# 29    do you like pasta?
# 30    the end!
# 32    we always try to bring the heavy. #metal #rt http://t.co/yao1e0xngw
# 40    check these out: http://t.co/roi2nsmejj http://t.co/3tj8zjin21 http://t.co/yduixefipe http://t.co/lxtjc87kls #nsfw
# 45    i gained 3 followers in the last week. you? know your stats and grow with http://t.co/tiyulif5c6
# 48    check these out: http://t.co/roi2nsmejj http://t.co/3tj8zjin21 http://t.co/yduixefipe http://t.co/lxtjc87kls #nsfw
# 49    first night with retainers in. it's quite weird. better get used to it; i have to wear them every single night for the next year at least.
# 54    noches el-bestia '@alexis_sanchez: happy to see my teammates and training hard ?? goodnight gunners.?????? http://t.co/uc4j4jhvgr'
# 103   'the man who can drive himself further once the effort gets painful is the man who will win.' \nroger bannister
# 105   'there is no victory at bargain basement prices.' dwight david eisenhower
# 107   'nobody remembers who came in second.' charles schulz
# 109   'the harder the conflict the more glorious the triumph.' thomas paine
# 120   #wisdomwed bonus - 5 minute daily habits that could really improve your life. how many do you already do? #lifehacks http://t.co/tbm9fqb8cw
# 125   sometimes you face difficulties not because you're doing something wrong but because you're doing something right. - joel osteen
# 126   'the only thing that stands between you and your dream is the will to try and the belief that it is actually possible.' - joel brown
# 127   praise god that we have ministry that tells it like it is!!! #now #wdyouth #biblestudy https://t.co/ujk0e5gbcc
# ...                                                                                                              ...
# 6917  noel back up
# 6937  reddit's new content policy shows that maybe reddit can't have it all http://t.co/yo3t8qho9h via @nkulw http://t.co/8odtzmvqar
# 6943  i feel so lucky rn
# 6949  #bbshelli seems pretty sure she's the one that's going to stay! #bb17
# 6952  it's my senior year i just wanna go all out
# 6975  all of this energy
# 6995  @ellenfromnowon 7-speed nexus shifter å£9! (for community cargo bike?) http://t.co/rjpjbwvfck
# 7066  ancient mayan tablet with hieroglyphics honors lowly king http://t.co/xh4dz1gpyw http://t.co/g0hsyh7yav
# 7073  ancient mayan tablet found in jungle temple http://t.co/qp6q8rs8on
# 7076  ancient mayan tablet with hieroglyphics honors lowly king http://t.co/im6m4xaen2
# 7077  ancient mayan tablet with hieroglyphics honors lowly king http://t.co/wqikqx9e3w
# 7078  diageo's ceo stresses that a board revolt at united spirits has not impacted indian operations http://t.co/gfs7usulgq
# 7079  rt '@livescience: ancient mayan tablet with hieroglyphics honors lowly king: http://t.co/dpgdnaoy4p http://t.co/4fcjfdkdzs
# 7080  ancient mayan tablet with hieroglyphics honors lowly king: a 1600-year-old mayan stone tablet describing the ... http://t.co/glpfu0uriz
# 7082  ancient mayan tablet found via http://t.co/lmumzkltln http://t.co/yebxxarybf http://t.co/srruqfffr6 http://t.co/cadzxagmsi
# 7088  diageo's ceo stresses that a board revolt at united spirits has not impacted indian operations http://t.co/stpoda901u
# 7098  #amsterdam pov video captures violent landing at amsterdam airport schiphol during a st... http://t.co/alumrgl40e http://t.co/8h2kctfb8i
# 7104  i don't understand 'taking' any life as a trophy. it's violent killing. http://t.co/neqw47e1uj #cecilthelion #badchoices #bantrophyhunting
# 7154  zone of the enders mgs2 god of war. rt @d_pagexxi: quote this with your favorite ps2 game
# 7165  #debatequestionswewanttohear if u start another war would u b willing 2 go 2 the war-zone yourself or send ur sons and/or daughters 2 fight?
# 7197  rare insight into #terror and how to fight it http://t.co/t6obvwaphw #cameroon #usa #whitehouse #es #fr #nigeria #uk #africa #de #ca #au #jp
# 7219  the thing with rules is break it once it becomes easier the next time.\nhttp://t.co/hgb1mc3irk  https://t.co/6ysxghc8gz
# 7241  #bigbrother #ch4 the x-37b's big brother revealed: boeing bags $6.6m contract to design ... - daily mail http://t.co/0migwcmtje
# 7243  @david_hurn @tokteacher why is there something in place to prevent skynet? because perhaps there should be! http://t.co/73umw2igrz
# 7264  eyes smile. pretty smile.  good hair. miss luhan in exo. ???????? http://t.co/y7o55by36f
# 7272  {info} baekhyun and suho will be attending the idol sports championship on august 10th\ncr: syjexo \n http://t.co/oazjpwueyr
# 7334  be ember aware! http://t.co/lzml1xb2nh
# 7342  i honestly wonder what it is that i had to do so wrong to lose everyone.
# 7440  acc to the study conducted by skims morethan 50% population in #kashmir suffer psychiatric disorders http://t.co/saf9mosksn #kashmirconflict
# 7494  the court system is truly broken indeed! but then its no surprise based on who it's run by! http://t.co/uu64wfg17m
#
#       target  cant_keywords
# 15    0       0
# 16    0       0
# 17    0       0
# 18    0       0
# 19    0       0
# 20    0       0
# 21    0       0
# 22    0       0
# 23    0       0
# 24    0       0
# 25    0       0
# 26    0       0
# 27    0       0
# 28    0       0
# 29    0       0
# 30    0       0
# 32    0       0
# 40    0       0
# 45    0       0
# 48    0       0
# 49    0       0
# 54    0       0
# 103   0       0
# 105   0       0
# 107   0       0
# 109   0       0
# 120   0       0
# 125   0       0
# 126   0       0
# 127   0       0
# ...  ..      ..
# 6917  0       0
# 6937  0       0
# 6943  0       0
# 6949  0       0
# 6952  0       0
# 6975  0       0
# 6995  0       0
# 7066  0       0
# 7073  1       0
# 7076  0       0
# 7077  0       0
# 7078  0       0
# 7079  0       0
# 7080  0       0
# 7082  0       0
# 7088  0       0
# 7098  1       0
# 7104  1       0
# 7154  0       0
# 7165  1       0
# 7197  1       0
# 7219  0       0
# 7241  0       0
# 7243  0       0
# 7264  0       0
# 7272  0       0
# 7334  1       0
# 7342  0       0
# 7440  1       0
# 7494  0       0
#
# [495 rows x 6 columns]

# %%
relacion_cant = df.groupby(['cant_keywords']).agg({'target':'mean'})
relacion_cant['proporcion_0'] = 1 - relacion_cant['target']
relacion_cant.columns = ['Proporcion de 1','Proporcion de 0']

# %%
relacion_cant
# Out:
#                Proporcion de 1  Proporcion de 0
# cant_keywords
# 0              0.167677         0.832323
# 1              0.327332         0.672668
# 2              0.520584         0.479416
# 3              0.794498         0.205502
# 4              0.840491         0.159509
# 5              0.956522         0.043478

# %%
import seaborn as sns

# %%
f,(ax_viol,ax_stack) = plt.subplots(2,sharex=True,gridspec_kw={'height_ratios':(.2,.8)},figsize=(10,7))
color = ["#0aec48","firebrick"]
color_violin = 'navy'
ax_viol.set_title("Proporcion  de Veracidad de Tweets segun cantidad de Keywords",size=20,pad=20)

x = relacion_cant.index
y =relacion_cant['Proporcion de 1']
z =relacion_cant['Proporcion de 0']
j = df['cant_keywords']
sns.violinplot(j,ax=ax_viol,color=color_violin,pad=8.0)
ax_stack.bar(x,y,bottom=z,color = "#0aec48",edgecolor='black',label = "Proporcion de Tweets con Target 1")
ax_stack.bar(x,z,color = "firebrick",edgecolor='black',label = "Proporcion de Tweets con Target 0")

ax_stack.legend(loc='upper right')
ax_viol.set_ylabel("Cantidad",fontsize=14)
ax_viol.set_xlabel("")
ax_stack.set_xlabel("Cantidad de Keywords",fontsize=14)
ax_stack.set_ylabel("Proporcion",fontsize = 14)
f.tight_layout(pad=0)
plt.savefig('Cantidad_Keywords.png',bbox_inches='tight')
plt.show()

# %%
data.head()
# Out:
#    id keyword location  \
# 0  1   NaN     NaN
# 1  4   NaN     NaN
# 2  5   NaN     NaN
# 3  6   NaN     NaN
# 4  7   NaN     NaN
#
#                                                                                                                                     text  \
# 0  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1  Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3  13,000 people receive #wildfires evacuation orders in California
# 4  Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
locations = data.groupby(['location','target']).agg({'text':'count'})

# %%
locations.head(200)
# Out:
#                                        text
# location                       target
#                                1       1
#   Glasgow                      0       1
#   Melbourne, Australia         0       1
#   News                         1       1
#   å_                           0       1
#  45å¡ 5'12.53N   14å¡ 7'24.93E 0       1
#  616 Û¢ Kentwood , MI         1       1
#  ? ??????? ? ( ?? å¡ ? ? ? å¡) 1       1
#  ?currently writing a book?    0       1
#  Alberta                       1       1
#  Alex/Mika/Leo|18|he/she/they  0       1
#  BC, US, Asia or Europe.       0       1
#  Baku & Erzurum                1       1
#  Blood Indian Reserve          0       1
#  Bouvet Island                 1       1
#  Eugene, Oregon                0       1
#  Indiana                       0       1
#  Jariana Town                  0       1
#  Little Rock, AR               0       1
#  Miami Beach                   0       1
#  Nevada Carson City,Freeman St 1       1
#  Neverland                     0       1
#  New Delhi                     0       1
#  New England                   1       1
#  Nxgerxa                       0       1
#  Quantico Marine Base, VA.     0       1
#  Queensland, Australia         0       1
#                                1       1
#  Road to the Billionaires Club 0       5
#                                1       1
# ...                                   ..
# ???                            1       2
# ???  Dreamz                    0       2
# ??? ?? ???????                 1       1
# ??? ??? ????? ??? ???.         1       1
# ??? ???? ??????                1       1
# ??? ???? ?f glory. ?           0       1
# ??? ?????????????              1       1
# ????                           0       2
# ???? ???????                   1       1
# ?????                          0       2
#                                1       2
# ????? ???? ????                1       1
# ??????                         0       3
#                                1       3
# ?????? ??? ?????? ????????     0       1
# ?????? ???? ??????             1       1
# ?????? in Yokohama Japan       1       1
# ??????? ??????? ????????       1       1
# ???????, ??'??????             0       1
# ???????, Texas                 0       1
# ???????? ?????????.            0       1
# ???????????                    0       1
# ??????????? ???????????..?     0       1
# ????????????                   1       1
# ?????????????, Thailand        1       1
# ??????????????                 1       1
# ??????????????????             1       1
# ????s ?? ????Ìø????Ì¡a         1       1
# ??t?a                          0       1
# ?@symbolicjensen?              0       1
#
# [200 rows x 1 columns]
